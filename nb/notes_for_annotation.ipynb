# %%
library(dplyr)
library(tidyverse)
library(stringr)

# %% [markdown]
# ## Extracted Parents -> Notes for Annotation
#
# Using the dataframe: extracted_parents.csv
#
# This notebook extracts notes that will be annotated for our project in Symbolic Methods. The notes will be annotated manually by two students, MetaMap, Usagi and our proposed method.
#
# For this project we are interested in the modifiers: **severe, significant or serious**
#
# From the original dataframe we:
# 1. remove notes that do not include spaces. This is because MetaMap requires the space separation of words
# 2. remove repeats e.g., pain and painful are both found in the criteria_string "... painful ...".
#    To avoid biasing our gold standard we remove these "repeats"
# 3. remove criteria_string that are less than 200 characters in length due to an indexing error
# 4. remove criteria_string in which the matched_string is not present
#
# From this editted dataframe we:
# 1. investigate the parent concepts that are most representative in the dataset
# 2. investigate the number of criteria_string that include the modifiers
# 3. ignore parent concepts that include the three modifiers of interest
#
# Finally, we create a dataset of notes for annotation that follow the criteria below
# 1. parent concepts included must have at least 10 instances where a criteria_string includes a modifier
# 2. For each parent concept, we choose 5 instances with a modifier and 5 without a modifier (10 total per parent)
#
# _Note_ In the dataset we include 5 instances for each parent in which the criteria_string includes a modifier. However, this modifier may not be applied the the matched_string but just has to be present in the criteria_string.
#
# **RESULT:** Dataframe with 77 unique parent_concept_ids. Total of 770 observations and 6 fields written to: **annotate_notes.csv**

# %%
mz_data <- read.delim("../data/extracted_parents.csv", sep = ",", stringsAsFactors = F)

# %%
# example of where matched_string is not present in criteria_string
mz_data %>% filter(NCT_id == "NCT01829919")
# Out:
#   NCT_id      matched_string
# 1 NCT01829919 major depressive disorder
# 2 NCT01829919 bipolar disorder
# 3 NCT01829919 depressive disorder
# 4 NCT01829919 depression
# 5 NCT01829919 psychotic disorder
# 6 NCT01829919 panic
#   criteria_string
# 1 sonality disorder; presence of any of the following psychiatric disorders within the\n        timeframes specified: Major Depressive Disorder-Lifetime; Dysthymia-Past 2 Years; Bipolar\n        Disorder-
# 2 story of clinical diagnosis of\n        depression; or treatment for depression; history of clinical diagnosis of border-line\n        personality disorder; presence of any of the following psychiatric
# 3 ty disorder; presence of any of the following psychiatric disorders within the\n        timeframes specified: Major Depressive Disorder-Lifetime; Dysthymia-Past 2 Years; Bipolar\n        Disorder-Lifeti
# 4 retion of study\n        medication; history of self-injurious behavior; history of clinical diagnosis of\n        depression; or treatment for depression; history of clinical diagnosis of border-line\n
# 5 ence of any of the following psychiatric disorders within the\n        timeframes specified: Major Depressive Disorder-Lifetime; Dysthymia-Past 2 Years; Bipolar\n        Disorder-Lifetime; Panic Disorde
# 6 imeframes specified: Major Depressive Disorder-Lifetime; Dysthymia-Past 2 Years; Bipolar\n        Disorder-Lifetime; Panic Disorder-Lifetime; Agoraphobia-Past Month; Social Phobia-Past\n        Month; O
#   parent_concept_id parent_concept_name
# 1 4152280           Major depressive disorder
# 2  436665           Bipolar disorder
# 3  440383           Depressive disorder
# 4  440383           Depressive disorder
# 5  436073           Psychotic disorder
# 6 4196358           Panic

# %%
# remove notes without spaces
notes_edit <- mz_data[str_detect(mz_data$criteria_string, " "), ]
# remove repeated NCTID with same parent concept
notes_edit <- notes_edit[rownames(unique(notes1000[,c("NCT_id", "parent_concept_id")])), ]
# remove notes less than 200 characters
notes_edit <- notes_edit[nchar(notes_edit$criteria_string) == 200, ]
# remove notes where matched_string is not in criteria_string
notes_edit <- notes_edit %>% rowwise() %>% 
                    filter(str_detect(string = tolower(criteria_string), pattern = matched_string))

# %%
# check point after editing original dataframe
table(nchar(notes_edit$criteria_string)))
notes_edit %>% filter(NCT_id == "NCT01829919")
# Out:
#    200
# 233365
#   NCT_id      matched_string
# 1 NCT01829919 major depressive disorder
# 2 NCT01829919 depressive disorder
# 3 NCT01829919 panic
#   criteria_string
# 1 sonality disorder; presence of any of the following psychiatric disorders within the\n        timeframes specified: Major Depressive Disorder-Lifetime; Dysthymia-Past 2 Years; Bipolar\n        Disorder-
# 2 ty disorder; presence of any of the following psychiatric disorders within the\n        timeframes specified: Major Depressive Disorder-Lifetime; Dysthymia-Past 2 Years; Bipolar\n        Disorder-Lifeti
# 3 imeframes specified: Major Depressive Disorder-Lifetime; Dysthymia-Past 2 Years; Bipolar\n        Disorder-Lifetime; Panic Disorder-Lifetime; Agoraphobia-Past Month; Social Phobia-Past\n        Month; O
#   parent_concept_id parent_concept_name
# 1 4152280           Major depressive disorder
# 2  440383           Depressive disorder
# 3 4196358           Panic

# %%
# Identify 100 most representative parent concepts
top100 <- notes_edit %>% group_by(parent_concept_id, parent_concept_name) %>% 
                        summarise(count = n()) %>% 
                        arrange(-count) %>% 
                        head(n = 100)
head(top100)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   parent_concept_id parent_concept_name   count
# 1  316866           Hypertensive disorder 28053
# 2  437312           Bleeding              25745
# 3 4329041           Pain                  18620
# 4  440383           Depressive disorder   13529
# 5  317009           Asthma                11751
# 6 4182210           Dementia               9314

# %%
# Found that the top 100 don't always have >= 5 instances with modifiers
# Check out how many strings have "severe", "significant" or "serious" (modifiers of interest)
severe_ids <- notes_edit %>% filter(!grepl(tolower(parent_concept_name), pattern = "severe|significant|serious")) %>%
                group_by(parent_concept_id, parent_concept_name) %>%
                summarise(count = n(),
                          severe = sum(str_detect(criteria_string, "severe|significant|serious"))) %>%
                arrange(-severe) %>%
                head(n = 100)
head(severe_ids)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”
#   parent_concept_id parent_concept_name   count severe
# 1  316866           Hypertensive disorder 28053 5164
# 2  437312           Bleeding              25745 3972
# 3  440383           Depressive disorder   13529 3030
# 4  317009           Asthma                11751 2643
# 5 4182210           Dementia               9314 2062
# 6 4329041           Pain                  18620 1819

# %%
# parent concepts that have at least 10 instances of criteria_string that includes modifier
parent_ids <- severe_ids %>% filter(severe >= 10) %>% select(parent_concept_id) %>% unlist() %>% unname()

# %%
# choose 5 with modifier and 5 without modifiers for these 77 parents
notes_770 <- notes_edit %>% filter(parent_concept_id %in% parent_ids) %>%
                mutate(w.mod = str_detect(criteria_string, "severe|significant|serious")) %>% 
                group_by(parent_concept_id, w.mod) %>% sample_n(size = 5)
# Out:
# Warning message:
# “Grouping rowwise data frame strips rowwise nature”

# %%
print(dim(notes_770))
head(notes_770, n = 20)
# Out:
# [1] 770   6
#    NCT_id      matched_string
# 1  NCT03937804 scoliosis
# 2  NCT00252252 scoliosis
# 3  NCT03329716 scoliosis
# 4  NCT03090971 scoliosis
# 5  NCT03404232 scoliosis
# 6  NCT01467882 scoliosis
# 7  NCT03581084 scoliosis
# 8  NCT01926275 scoliosis
# 9  NCT01784094 scoliosis
# 10 NCT02131090 scoliosis
# 11 NCT02081430 muscle wasting
# 12 NCT01571674 muscle wasting
# 13 NCT03078543 muscular atrophy
# 14 NCT02668835 muscular atrophy
# 15 NCT03981575 muscle wasting
# 16 NCT00394043 muscle atrophy
# 17 NCT03424707 muscular atrophy
# 18 NCT02741076 amyotrophy
# 19 NCT03517319 muscle atrophy
# 20 NCT01427361 muscular atrophy
#    criteria_string
# 1  ve pulmonary disease, chronic obstructive airway disease,\n             emphysema, chronic bronchitis, lung transplant, kyphoscoliosis, sarcoidosis,\n             bronchopulmonary dysplasia, cystic fibr
# 2  ar disease (eg. old polio, bilateral diaphragm\n             paralysis) or chest wall disease (eg. idiopathic scoliosis, thoracoplasty)\n\n          -  Recruited from 1300 patients attending Royal Brompt
# 3  en wearing underarm (Boston) bracing, and who have reached\n             skeletal maturity based on the Scoliosis Research Society (SRS) standardized criteria:\n             Risser stage ≥4, >2 years po
# 4  -  a distinct osseous lesion, such as sphenoid wing dysplasia, pseudoarthrosis of the\n             tibia, macrocephaly, or scoliosis\n\n          -  a first-degree relative with NF1\n\n          -  Presen
# 5  pine\n\n          -  Relevant peripheral neuropathy\n\n          -  Acute denervation subsequent to a radiculopathy\n\n          -  Scoliosis with Cobb angle greater than 25°\n\n          -  Spondylolisthesis
# 6   or other study endpoints (e.g. chronic steroid use [except mild topical steroids],\n             renal failure, diabetes, moderate to severe scoliosis, previously treated intracranial\n             tum
# 7  tis, vocal cord dysfunction\n             (that is the sole cause of respiratory symptoms and at the PI's discretion), severe\n             scoliosis or chest wall deformities that affect lung function,
# 8  nced\n             bronchiectases, active tuberculosis, post tuberculosis syndrome, pneumonia, severe\n             kyphoscoliosis, tracheostoma, neuromuscular diseases, or any other disorder, which\n
# 9  :\n\n          -  previous severe back or lower extremity injury or surgery\n\n          -  major structural spinal deformity (scoliosis, kyphosis, stenosis)\n\n          -  ankylosing spondylitis or rheuma
# 10 men\n\n          -  BMI < 50\n\n        Exclusion Criteria:\n\n          -  BMI >50\n\n          -  Documented diagnosis of scoliosis and/or other significant lumbar spinal pathology\n\n          -  Previous lu
# 11 nce of central nervous system involvement such as exaggerated reflexes, changes\n             in sensation in the hands, muscle wasting in the hands, impaired sensation of the\n             face, altere
# 12  of central nervous system involvement, to include hyperreflexia, sensory\n             disturbances in the hand, intrinsic muscle wasting of the hands, unsteadiness during\n             walking, nystag
# 13 ct has conditions that may interfere with the TKA survival or outcome (e.g.\n             Paget's or Charcot's disease, vascular insufficiency, muscular atrophy, uncontrolled\n             diabetes mell
# 14 e - Multiple sclerosis, amyotrophic lateral sclerosis, motor\n             neuritis, progressive bulbar palsy, progressive muscular atrophy, spinal muscular\n             atrophy\n\n          -  Significa
# 15 udy:\n\n          -  Known CTG repeat expansion size less than 100 repeats, unless there are clear cut\n             signs of limb weakness and muscle wasting. This is in order to obtain a muscle tissue\n
# 16 atency greater than\n             0.2 ms\n\n        Exclusion Criteria:\n\n          -  severe CTS that has progressed to muscle atrophy\n\n          -  pregnancy\n\n          -  previous wrist surgery on the
# 17 g confirmed\n             degenerative spondylosis, severe arthritis or severe osteoporosis) (2) myositis,\n             muscular atrophy, myotonia, myasthenia (3) peptic ulcer or duodenal ulcer (4)\n
# 18 on, severe or progressive lower extremity weakness or numbness, bowel or\n             bladder dysfunction as a result of cauda equina compression, diabetic amyotrophy,\n             meningitis, diskiti
# 19 fore screening\n\n          -  history or plan for tendon lengthening surgery\n\n          -  significant contracture ormuscle atrophy at the target joint or muscle\n\n          -  concurrent treatment with
# 20  Exclusion Criteria:\n\n          1. Patient with infection or sepsis.\n\n          2. Patient with any vascular insufficiency, muscular atrophy, or neuromuscular disease\n             severe enough to com
#    parent_concept_id parent_concept_name          w.mod
# 1  72418             Scoliosis deformity of spine FALSE
# 2  72418             Scoliosis deformity of spine FALSE
# 3  72418             Scoliosis deformity of spine FALSE
# 4  72418             Scoliosis deformity of spine FALSE
# 5  72418             Scoliosis deformity of spine FALSE
# 6  72418             Scoliosis deformity of spine  TRUE
# 7  72418             Scoliosis deformity of spine  TRUE
# 8  72418             Scoliosis deformity of spine  TRUE
# 9  72418             Scoliosis deformity of spine  TRUE
# 10 72418             Scoliosis deformity of spine  TRUE
# 11 78236             Muscle atrophy               FALSE
# 12 78236             Muscle atrophy               FALSE
# 13 78236             Muscle atrophy               FALSE
# 14 78236             Muscle atrophy               FALSE
# 15 78236             Muscle atrophy               FALSE
# 16 78236             Muscle atrophy                TRUE
# 17 78236             Muscle atrophy                TRUE
# 18 78236             Muscle atrophy                TRUE
# 19 78236             Muscle atrophy                TRUE
# 20 78236             Muscle atrophy                TRUE

# %%
write.csv(file = "../data/annotate_notes.csv",
          x = notes_770, row.names = FALSE)
